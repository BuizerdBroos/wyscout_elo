# %%
# create dictionary to allow merge with ELO dataset 

dict = {
    
    # BELGIUM 
        # Jupiler Pro League
        'Waasland-Beveren': 'Beveren', 'OH Leuven' : 'Leuven', 'Beerschot-Wilrijk': 'Beerschot AC',
       'KV Oostende' : 'Oostende', 'Zulte-Waregem' : 'Zulte Waregem', 'Standard Liège' : 'Standard', 'Club Brugge' : 'Brugge',
       'Sint-Truiden' : 'St Truiden', 
    
    # ENGLAND
    
        # Premier League
        'Manchester City' : 'Man City', 'Leeds United' : 'Leeds',
       'Wolverhampton Wanderers' : 'Wolves', 'Manchester United' : 'Man United', 'Newcastle United' : 'Newcastle',
       'West Bromwich Albion' : 'West Brom', 'Brighton & Hove Albion' : 'Brighton',
       'Tottenham Hotspur' : 'Tottenham', 'Leicester City' : 'Leicester', 'West Ham United': 'West Ham',
       'Norwich City' : 'Norwich', 
    
        # Championship
        'Wigan Athletic':'Wigan', 'Charlton Athletic':'Charlton', 'Hull City':'Hull', 'Cardiff City': 'Cardiff', 'Sheffield Wednesday': 'Sheffield Weds',
       'Nottingham Forest':'Forest', 'Birmingham City':'Birmingham', 'Queens Park Rangers':'QPR',
       'Preston North End':'Preston', 'Derby County':'Derby',
       'Swansea City':'Swansea', 'Stoke City':'Stoke', 'Blackburn Rovers':'Blackburn', 'Luton Town':'Luton',
       'Huddersfield Town':'Huddersfield', 'Wycombe Wanderers': 'Wycombe',
       'Rotherham United':'Rotherham', 'Coventry City':'Coventry',  
    
    # FRANCE 
    
        # Ligue 1
        'Angers SCO' : 'Angers', 'Nîmes': 'Nimes', 'PSG' : 'Paris SG',
       'Olympique Marseille':'Marseille', 'Saint-Étienne': 'Saint-Etienne', 'Olympique Lyonnais' : 'Lyon',
       'Amiens SC' : 'Amiens', 
    
        # ligue 2
        'Paris':'Paris FC', 'Chambly':'Chambly Oise',
       'Châteauroux':'Chateauroux', 'Orléans':'Orleans', 
    
    # ITALY 
    
        # Serie A
        'Hellas Verona': 'Verona', 'Internazionale' : 'Inter', 'SPAL' : 'Spal',
    
        # Serie B
        'Virtus Entella':'Entella',

    # GERMANY
    
        # Bundesliga
        'Bayern München' : 'Bayern', 'Köln' : 'Koeln',
       'Eintracht Frankfurt' : 'Frankfurt', 'Hertha BSC' : 'Hertha', "Borussia M'gladbach" : 'Gladbach',
       'Schalke 04':'Schalke', 'Mainz 05' : 'Mainz', 'Bayer Leverkusen' : 'Leverkusen', 'Borussia Dortmund' : 'Dortmund',
       'Werder Bremen' : 'Werder', 'Fortuna Düsseldorf' : 'Duesseldorf', 
    
        # 2nd Bundesliga 
        'Karlsruher SC':'Karlsruhe', 'Darmstadt 98':'Darmstadt', 'Arminia Bielefeld' : 'Bielefeld', 
       'Nürnberg':'Nuernberg', 'Holstein Kiel':'Holstein', 'Hamburger SV':'Hamburg',
       'Osnabrück':'Osnabrueck', 'Greuther Fürth':'Fuerth', 'Erzgebirge Aue':'Aue', 'Eintracht Braunschweig':'Braunschweig', 
          'Würzburger Kickers':'Wuerzburg', 'Jahn Regensburg':'Regensburg', 'Hannover 96':'Hannover', 'St. Pauli':'St Pauli',
    
    # SPAIN
    
        # Primera Division
        'Athletic Bilbao' : 'Bilbao', 'Cádiz' : 'Cadiz',
       'Real Sociedad' : 'Sociedad', 'Celta de Vigo' : 'Celta', 'Real Betis' : 'Betis', 'Real Valladolid' : 'Valladolid',
       'Deportivo Alavés' : 'Alaves', 'Leganés' : 'Leganes', 'Atlético Madrid' : 'Atletico', 
         
        # Segunda Division
        'Logroñés':'Logrones','Castellón':'Castellon',
       'UD Logroñés':'Logroñés', 'Sporting Gijón':'Gijón', 'Real Oviedo':'Oviedo', 'Alcorcón':'Alcorcon',
       'Real Zaragoza':'Zaragoza', 'Málaga':'Malaga', 'Mirandés':'Mirandes', 'Almería':'Almeria', 'Gijón':'Gijon', 'Extremadura UD':'Extremadura', 
        'Racing Santander':'Santander',  'Deportivo La Coruña':'Depor'
    
    # AUSTRIA
       'Wehen Wiesbaden':'Wehen', 'WSG Swarovski Tirol':'Wattens', 'LASK Linz':'LASK', 'Wolfsberger AC':'Wolfsberg', 'Dynamo Dresden':'Dresden',
       'Rheindorf Altach':'Altach', 'St. Pölten':'St Poelten', 'St Polten':'St Poelten',
    
    # NETHERLANDS
         'ADO Den Haag':'Den Haag', 'RKC Waalwijk':'Waalwijk', 'Fortuna Sittard':'Sittard', 'AZ':'Alkmaar',
       'VVV Venlo':'Venlo', 'PEC Zwolle':'Zwolle', 
    
    # DENMARK
          'AaB':'Aalborg', 'OB':'Odense', 'SønderjyskE':'SonderjyskE',
       'Nordsjælland':'Nordsjaelland', 'Brøndby':'Brondby', 'København':'FC Kobenhavn', 'AGF':'Aarhus', 
    
    # SWEDEN
          'IFK Göteborg':'Goeteborg', 'Östersunds FK':'Ostersund', 'Mjällby':'Mjaellby', 'Malmö FF':'Malmoe', 'Häcken':'Haecken',
       'Falkenberg':'Falkenbergs', 'Örebro':'Oerebro', 'Orebro':'Oerebro',
       'Djurgården':'Djurgarden', 'Djugarden':'Djurgarden', 'Varberg':'Varbergs', 'Sirius':'IK Sirius', 'IFK Norrköping':'Norrkoeping',
     
    
    # NORWAY
        'Odds':'Odd Grenland', 'Sarpsborg 08':'Sarpsborg', 'Viking':'Viking',
       'Haugesund':'Haugesund', 'Kristiansund':'Kristiansund', 'Rosenborg':'Rosenborg', 'Molde':'Molde', 
       'Bodø / Glimt':'Bodoe Glimt', 'Strømsgodset':'Stromsgodset',
       'Mjøndalen':'Mjondalen', 'Vålerenga':'Valerenga', 'Stabæk':'Stabaek', 
    
    # TURKEY
         'Göztepe':'Goeztepe', 'Fatih Karagümrük':'Fatih Karaguemruek',
       'Kayserispor':'Kayseri', 'Ankaragücü':'Ankaraguecue', 'BB Erzurumspor':'Erzurum BB', 'Kasımpaşa':'Kasimpasa',
       'Fenerbahçe':'Fenerbahce', 'İstanbul Başakşehir':'Basaksehir', 'Gaziantep':'Gaziantep FK',
       'Yeni Malatyaspor':'Malatyaspor', 'Beşiktaş':'Besiktas', 'Gençlerbirliği':'Genclerbirligi', 'Basaksehir':'Bueyueksehir',
       
    
    # RUSSIA
        'Arsenal Tula':'Tula', 'Dinamo Moskva':'Dynamo Moskva', "Rubin Kazan'":'Rubin Kazan',
       'Lokomotiv Moskva':'Lok Moskva', 'Krasnodar':'FC Krasnodar', 'Khimki':'FC Khimki', 'Rotor':'Rotor Volgograd',
       'Krylya Sovetov':'Kryliya Sovetov', 'Ural':'Sverdlovsk', 'Akhmat Grozny':'Terek Grozny',
    
    # SWITZERLAND
        'St. Gallen':'StGallen', 'Neuchâtel Xamax':'Xamax', 'Desportivo Aves':'Aves', 'Vitória Setúbal':'Setubal',
       'Lausanne Sport':'Lausanne', 'Zürich':'Zuerich',
    
    # PORTUGAL
         'Famalicão':'Famalicao', 'Vitória Guimarães':'Guimaraes',
       'Paços de Ferreira':'Pacos Ferreira', 'Sporting CP':'Sporting', 'Marítimo':'Maritimo', 'Sporting Braga':'Braga',
       
      
       
     }

# replace values according to the dictionary
df = df.replace({"Team" : dict})
